# %% [markdown]
# <a href="https://colab.research.google.com/github/suphalaksana/data_viz_2022/blob/main/Pandas101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd  #package pandas ใช้ในการจัดการข้อมูลที่เป็นตาราง พวกไฟล์ CSV

# %% [markdown]
# .CSV = Comma Separated Values

# %% [markdown]
# data.go.th

# %%
from google.colab import drive  #เชื่อมต่อ google drive กับ colab
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os  

path = '/content/drive/My Drive/dataviz_2021_data'

# %%
covid_file_path = os.path.join(path,'pm-20-jan-2021.csv') 
print(covid_file_path)
# Out:
# /content/drive/My Drive/dataviz_2021_data/pm-20-jan-2021.csv

# %%
a = path + '/pm-18-jan-2021.csv' 
print(a)
# Out:
# /content/drive/My Drive/dataviz_2021_data/pm-18-jan-2021.csv

# %% [markdown]
# ## load data to memory

# %%
data_covid = pd.read_csv(covid_file_path)
data_covid  #มี 12653 แถว  10 หลัก
# Out:
#          No.  ...                                         risk
# 0          1  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          2  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          3  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 3          4  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 4          5  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# ...      ...  ...                                          ...
# 12648  12649  ...                             State Quarantine
# 12649  12650  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12650  12651  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651  12652  ...                                Cluster ระยอง
# 12652  12653  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [12653 rows x 10 columns]

# %%
data_covid.head()  #เอามาแค่หัวตาราง
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [5 rows x 10 columns]

# %% [markdown]
# NaN = Not a Number ไม่มีค่า

# %%
data_covid.head(20)  #โชว์ 20 ตัวแรก
# Out:
#     No.  ...                                               risk
# 0     1  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 1     2  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 2     3  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 3     4  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 4     5  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 5     6  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 6     7  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 7     8  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 8     9  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 9    10  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 10   11  ...        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11   12  ...        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12   13  ...        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 13   14  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# ...

# %%
data_covid.tail()  #ท้ายตาราง
# Out:
#          No.  ...                                         risk
# 12648  12649  ...                             State Quarantine
# 12649  12650  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12650  12651  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651  12652  ...                                Cluster ระยอง
# 12652  12653  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [5 rows x 10 columns]

# %%
data_covid.shape  #ดูขนาดของข้อมูล
# Out:
# (12653, 10)

# %% [markdown]
# ## ชี้ค่าในตาราง

# %% [markdown]
# #### basic

# %%
data_covid['province_of_onset']
# Out:
# 0        กรุงเทพมหานคร
# 1        กรุงเทพมหานคร
# 2               นครปฐม
# 3        กรุงเทพมหานคร
# 4        กรุงเทพมหานคร
#              ...
# 12648           ชลบุรี
# 12649            ระยอง
# 12650            ระยอง
# 12651            ระยอง
# 12652              ตาก
# Name: province_of_onset, Length: 12653, dtype: object

# %%
data_covid['province_of_onset'][4]  #ชี้ชื่อ column ก่อน  , ลำดับ row
# Out:
# 'กรุงเทพมหานคร'

# %%
data_covid['risk'][12649]
# Out:
# 'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้'

# %% [markdown]
# #### .iloc

# %%
data_covid.iloc[4,7]
# Out:
# 'กรุงเทพมหานคร'

# %% [markdown]
# ## Table slicing

# %% [markdown]
# #### ตัดมาเฉพาะ column ที่ต้องการ

# %%
smaller_table = data_covid[['announce_date','province_of_onset','risk']]  #เลือกมาเฉพาะชื่อคอลัมน์ที่ต้องการ  เป็น list ลำดับมีความสำคัญ
smaller_table
# Out:
#       announce_date  ...                                         risk
# 0         1/12/2020  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1         1/17/2020  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 2         1/22/2020  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 3         1/22/2020  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 4         1/24/2020  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# ...             ...  ...                                          ...
# 12648     1/20/2021  ...                             State Quarantine
# 12649     1/20/2021  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12650     1/20/2021  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651     1/20/2021  ...                                Cluster ระยอง
# 12652     1/20/2021  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [12653 rows x 3 columns]

# %% [markdown]
# #### ตัดเฉพาะ rows ที่ต้องการ

# %% [markdown]
# ##### แบบง่าย แต่ใช้การอะไรไม่ค่อยจะได้ (มองเป็น array แล้วตัดแบบ array)

# %%
data_covid.iloc[1:5,:]  #เลือกตั้งแต่แถวที่1 ถึง แถว 4    แล้วเอาทุกๆคอลัมน์
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [4 rows x 10 columns]

# %% [markdown]
# แบบ advanced แต่ใช้ประโยชน์ได้เยอะกว่า (ตัดแบบใช้ logic query)

# %% [markdown]
# $pddf$[list_of_logical_values] คือการเลือก row ที่ logical values เป็น True

# %%
data_covid['province_of_onset']
# Out:
# 0        กรุงเทพมหานคร
# 1        กรุงเทพมหานคร
# 2               นครปฐม
# 3        กรุงเทพมหานคร
# 4        กรุงเทพมหานคร
#              ...
# 12648           ชลบุรี
# 12649            ระยอง
# 12650            ระยอง
# 12651            ระยอง
# 12652              ตาก
# Name: province_of_onset, Length: 12653, dtype: object

# %%
data_covid['province_of_onset']=='ขอนแก่น'  #สนใจ provice_of_onset ที่มีค่าาเท่ากับขอนแก่น  ถ้าเจอขอนแก่นจะเป็น True  ไม่ใช่จะเป็น False
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12648    False
# 12649    False
# 12650    False
# 12651    False
# 12652    False
# Name: province_of_onset, Length: 12653, dtype: bool

# %%
data_covid[data_covid['province_of_onset']=='ขอนแก่น']
# Out:
#          No.  ...                                           risk
# 180      181  ...                                        สนามมวย
# 462      463  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1466    1467  ...                  คนไทยเดินทางกลับจากต่างประเทศ
# 1970    1971  ...  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 2637    2638  ...                  สัมผัสผู้เดินทางจากต่างประเทศ
# 2673    2674  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 5948    5949  ...                              Cluster สมุทรสาคร
# 6082    6083  ...                              Cluster สมุทรสาคร
# 9333    9334  ...                           อยู่ระหว่างการสอบสวน
# 9334    9335  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 10610  10611  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11517  11518  ...                           อยู่ระหว่างการสอบสวน
# 11697  11698  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...

# %%
data_covid[data_covid['age']>=70]  #สนใจคนที่อายุมากกว่าหรือเท่ากับ 70
# Out:
#          No.  ...                                               risk
# 1          2  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          3  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 7          8  ...                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 24        25  ...  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# 82        83  ...                                            สนามมวย
# ...      ...  ...                                                ...
# 11694  11695  ...      ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 11700  11701  ...        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11730  11731  ...                                  Cluster สมุทรสาคร
# 11741  11742  ...                               อยู่ระหว่างการสอบสวน
# 12102  12103  ...                                  Cluster สมุทรสาคร
#
# [245 rows x 10 columns]

# %% [markdown]
# การชี้ค่าในตารางด้วย data_covid[***x***] ค่า ***x*** สามารถมีค่าที่ใส่เข้าไปได้ 2 แบบ
#
#
# 1.   ชื่อ column
# 2.   ใส่ rows ที่ต้องการ (ใส่ list ที่มี***ขนาดเท่ากับจำนวนแถว*** แล้วบอกว่าเอา แถวไหนบ้างโดยใช้ logical expression (```True```/```False```))

# %%
eight_rows_covid = data_covid.iloc[:8,3:] # ตารางตัวอย่าง  #เอา ข้อมูล 8 ตัวแรก  #ตารางตัวอย่าง
eight_rows_covid
# Out:
#     sex   age  ... district_of_onset                              risk
# 0  หญิง  61.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1  หญิง  74.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2  หญิง  73.0  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3   ชาย  68.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4  หญิง  66.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5  หญิง  33.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 6  หญิง  57.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 7  หญิง  73.0  ...            หัวหิน  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [8 rows x 7 columns]

# %%
eight_rows_covid[[True,False,True,True,False,True,False,False]]   #2.   ใส่ list ที่มีค่า logic ของ แต่ละ row โดยที่ค่า True คือเลือก  และ False คือ ไม่เลือก ใส่ rows ที่ต้องการ
# Out:
#     sex   age  ... district_of_onset                              risk
# 0  หญิง  61.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2  หญิง  73.0  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3   ชาย  68.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5  หญิง  33.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [4 rows x 7 columns]

# %%
eight_rows_covid['province_of_onset'] == 'กรุงเทพมหานคร'  #สร้าง list ของ logical expression
#เจอกรุงเทพ จะเป็น True
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# Name: province_of_onset, dtype: bool

# %%
eight_rows_covid[eight_rows_covid['province_of_onset'] == 'กรุงเทพมหานคร']  #เราเอา 2 บรรทัดบนมาบวกกัน
# Out:
#     sex   age  ... district_of_onset                              risk
# 0  หญิง  61.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1  หญิง  74.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3   ชาย  68.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4  หญิง  66.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5  หญิง  33.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 6  หญิง  57.0  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [6 rows x 7 columns]

# %%
eight_rows_covid['district_of_onset'] == 'เมือง'
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# Name: district_of_onset, dtype: bool

# %%
import numpy as np

# %% [markdown]
# $isnull$() ใช้ตรวจสอบว่าเป็น NaN หรือไม่

# %%
eight_rows_covid['district_of_onset'].isnull()  #ตรงไหนค่าว่างจะเป็น True
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# Name: district_of_onset, dtype: bool

# %% [markdown]
# #Quiz(ให้ใช้เฉพาะที่อาจารย์สอนไปแล้วในวิชานี้)
#
# 1.   คำนวณ อายุเฉลี่ย ของผู้ชาย ในข้อมูลทั้งหมด
# 2.   คำนวณ อายุเฉลี่ย ของผู้ชาย ในจังหวัดขอนแก่น
#
# 3. หาจำนวนผู้ป่วยที่ไม่ใช่คนไทย

# %% [markdown]
# หาอายุเฉลี่ยของเพศหญิง

# %%
this_data = data_covid[['sex','age','province_of_onset']]  #เลือกคอลัมน์ที่จะใช้

# %%
this_data  #print ออกมา
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [12653 rows x 3 columns]

# %%
female = this_data[this_data['sex']=='หญิง']  #เลือกจากตาราง this data เลือกมาแค่ที่เป็นผู้หญิง
female
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 4      หญิง  66.0     กรุงเทพมหานคร
# 5      หญิง  33.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [5332 rows x 3 columns]

# %%
female['age']  #ชี้คอลัมน์ที่เป็นอายุของเพศหญิง
# Out:
# 0        61.0
# 1        74.0
# 2        73.0
# 4        66.0
# 5        33.0
#          ...
# 12648    44.0
# 12649    52.0
# 12650    23.0
# 12651    29.0
# 12652    22.0
# Name: age, Length: 5332, dtype: float64

# %%
sum = 0  #เริ่มต้นมาเป็น 0 เพราะสร้างตัวแปร sum มารับค่าที่จะเอามาบวกกันทั้งหมด เป็นเลขอื่นไม่ได้เพราะถ้าเอามาบวกกันเรื่อยๆค่ามันจะเพี้ยน(คุณสมบัติการบวกทั่วไป)
N = 0  #นับว่ามีคนทั้งหมดกี่คน เพราะข้อมูลอาจจะมีค่าว่าง
for a in female['age']:  #วนลูปค่าอายุ
    
    if a > 0:  #เช็คว่ามากกว่า 0 คืออายุ คนปกติ ไม่มีข้อมูลผิดพลาด
        sum += a # sum = sum + a  #ถ้า a มากกว่า 0 ก็จะนำค่าใารวมใน  sum
        N += 1  #คำนวนจำนวนคนทั้งหมดใน sum

print(f'อายุเฉลี่ย ของ ผู้ป่วยหญิง {sum/N}')  #sum/n = อายุเฉลี่ยของผู้ป่วยหญิง
# Out:
# อายุเฉลี่ย ของ ผู้ป่วยหญิง 36.63955450022614

# %%
female_KK = female[female['province_of_onset']=='ขอนแก่น']  #สนใจข้อมูลผู้ป่วยหญิงในจังหวัดขอนแก่น

sum = 0
N = 0
for a in female_KK['age']:#วนลูปในค่าอายุ
    
    if a > 0:
        sum += a # sum = sum + a
        N += 1

print(f'อายุเฉลี่ย ของ ผู้ป่วยหญิง ในจังหวัดขอนแก่น {sum/N}')
# Out:
# อายุเฉลี่ย ของ ผู้ป่วยหญิง ในจังหวัดขอนแก่น 41.57142857142857

# %% [markdown]
# ข้อ 1  คำนวณ อายุเฉลี่ย ของผู้ชาย ในข้อมูลทั้งหมด

# %%
male = this_data[this_data['sex']=='ชาย']  #เลือกจากตาราง this data เลือกมาแค่ที่เป็นผู้ชาย

# %%
male['age']#ชี้คอลัมน์ที่เป็นอายุของเพศชาย
# Out:
# 3        68.0
# 8        63.0
# 10       33.0
# 11       61.0
# 12        6.0
#          ...
# 12640    66.0
# 12641    29.0
# 12643    39.0
# 12646    18.0
# 12647    42.0
# Name: age, Length: 4819, dtype: float64

# %%
sum = 0  #ค่าเริ่มต้นเท่ากับ 0 จะไม่เอาค่าติดลบมาคิด
N = 0
for a in male['age']:  #วนลูปเข้าไปในอายุเพศชาย
    
    if a > 0:
        sum += a # sum = sum + a
        N += 1

print(f'อายุเฉลี่ย ของ ผู้ป่วยชาย {sum/N}')
# Out:
# อายุเฉลี่ย ของ ผู้ป่วยชาย 39.46076940331987

# %% [markdown]
# ข้อ 2 คำนวณ อายุเฉลี่ย ของผู้ชาย ในจังหวัดขอนแก่น

# %%
male_KK = male[male['province_of_onset']=='ขอนแก่น']

sum = 0
N = 0
for a in male_KK['age']:
    
    if a > 0:
        sum += a # sum = sum + a
        N += 1

print(f'อายุเฉลี่ย ของ ผู้ป่วยชาย ในจังหวัดขอนแก่น {sum/N}')
# Out:
# อายุเฉลี่ย ของ ผู้ป่วยชาย ในจังหวัดขอนแก่น 26.571428571428573

# %% [markdown]
# ข้อ 3 หาจำนวนผู้ป่วยที่ไม่ใช่คนไทย

# %%
import numpy as np

# %%
np.sum(data_covid['nationality'].dropna() != 'Thailand')  #เครื่องหมาย  != เลือกจากตาราง data covid ที่ไม่ใช่ประเทศไทย  # .dropna คือลบค่าว่างที่มีอยู่ออก
# Out:
# 4129

# %% [markdown]
# การจัดการ Missing Value
#
# - ลบ record ที่เป็น missing
# - แทนที่ ค่า missing ด้วยค่าที่เหมาะสม mean, default, category-unknown
# - ใช้ ค่าจาก columns อื่นๆ ช่วยประมาณค่า ค่าใน column ที่หายไป (regression, deep learning, etc.)

# %% [markdown]
# ### ลบ record (dropna)
#
# missing = ```None``` ```NA```(not autorized) ```NaN``` (not a number)

# %%
this_data
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [12653 rows x 3 columns]

# %%
this_data.shape #(12423, 3)  # ดูขนาด  (แถว,คอลัมน์)
# Out:
# (12653, 3)

# %%
this_data.dropna()#เจอ missing จะลบแถว (row) นั้นไปเลย
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [8478 rows x 3 columns]

# %%
print(data_covid.shape)  
print(data_covid.dropna().shape)   #ลบค่าmissing เหลือข้อมูล 6655 แถว  10 คอลัมน์
# Out:
# (12653, 10)
# (6655, 10)

# %%
this_data.dropna(subset=['age','sex'])  #สนใจ age   sex
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [8880 rows x 3 columns]

# %%
print(this_data.dropna().shape)  #ลบค่า missing ทุกคอลัมน์
print(this_data.dropna(subset=['sex','age']).shape)  # ลบค่า missing ของ sex   age
# Out:
# (8478, 3)
# (8880, 3)

# %% [markdown]
# #ตรวจสอบ Missing(isnull())

# %%
this_data.isnull()  #ดูว่ามีค่า missing มั้ย
# Out:
#          sex    age  province_of_onset
# 0      False  False              False
# 1      False  False              False
# 2      False  False              False
# 3      False  False              False
# 4      False  False              False
# ...      ...    ...                ...
# 12648  False  False              False
# 12649  False  False              False
# 12650  False  False              False
# 12651  False  False              False
# 12652  False  False              False
#
# [12653 rows x 3 columns]

# %%
this_data.isnull().any() #   .any() เอาค่าความจริงใน column มา OR กัน  เราจะเห็นค่า TRUE
# Out:
# sex                  True
# age                  True
# province_of_onset    True
# dtype: bool

# %%
this_data.isnull().all() # .all() เอาค่าความจริงใน column มา AND กัน
# Out:
# sex                  False
# age                  False
# province_of_onset    False
# dtype: bool

# %%
this_data.isnull().any().any()  #  .any().any() เอามาเรียงต่อกัน TRUE คือ มีค่า missing  , FALSE ไม่มีค่า missing
# Out:
# True

# %%
this_data.dropna(subset=['sex','age']).isnull().any()  #sex  age ไม่มีค่า missingแล้วเพราะเป็น False  #province_of_onset ยังมีค่า misssing อยู่
# Out:
# sex                  False
# age                  False
# province_of_onset     True
# dtype: bool

# %%
this_data.dropna(subset=['sex','age'])
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [8880 rows x 3 columns]

# %% [markdown]
# ### 1. เพื่อให้ได้ผลลัพธ์การจัดการ ```dropna()``` ต้องเอาตัวแปรมารับ

# %%
this_data_nonull = this_data.dropna(subset=['sex','age'])

# %%
this_data_nonull.isnull().any()  #sex  age ไม่มีค่า missingแล้วเพราะเป็น False  #province_of_onset ยังมีค่า misssing อยู่
# Out:
# sex                  False
# age                  False
# province_of_onset     True
# dtype: bool

# %% [markdown]
# ### 2. update ตารางด้วยตัวแปร ```inplace```

# %%
this_data.dropna(subset=['sex','age'],inplace=True)  # inplace =True คืออัพเดตตาราง
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
this_data.isnull().any()  #อัพเดตาราง
# Out:
# sex                  False
# age                  False
# province_of_onset     True
# dtype: bool

# %%
aa = this_data.dropna(subset=['sex','age'],inplace=True)  #อย่าทำแบบนี้
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
aa  #ไม่แสดงผล เพราะค่าที่ไปรับเป็น NaN

# %% [markdown]
# ### แทน missing ด้วยค่าที่เหมาะสม (```fillna()```)

# %%
this_data = data_covid[['sex','age','province_of_onset']]

# %%
this_data
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [12653 rows x 3 columns]

# %%
print(f'จำนวน record ก่อน drop missing ใน province {this_data.shape[0]}')
print(f'จำนวน record หลัง drop missing ใน province {this_data.dropna(subset=["province_of_onset"]).shape[0]}')
# Out:
# จำนวน record ก่อน drop missing ใน province 12653
# จำนวน record หลัง drop missing ใน province 10662

# %% [markdown]
# ### 1. แทนด้วย class ใหม่

# %%
this_data_updated = this_data.fillna(value={'sex':'ไม่รู้', 'age':-99, 'province_of_onset':'ไม่รู้'})  # เลข -99 คือการใสเลขที่ไม่ซ้ำจากอันเดิม  #ตัวแปรชื่อ value  #แทนค่า missing ด้วย 'ไม่รู้'
this_data_updated.head()
# Out:
#     sex   age province_of_onset
# 0  หญิง  61.0     กรุงเทพมหานคร
# 1  หญิง  74.0     กรุงเทพมหานคร
# 2  หญิง  73.0            นครปฐม
# 3   ชาย  68.0     กรุงเทพมหานคร
# 4  หญิง  66.0     กรุงเทพมหานคร

# %%
this_data_updated.tail(15)  #ดู 15 ค่าแรก  #แทนค่า missing ด้วย 'ไม่รู้'
# Out:
#           sex   age province_of_onset
# 12638  ไม่รู้ -99.0         สมุทรสาคร
# 12639  ไม่รู้ -99.0         สมุทรสาคร
# 12640     ชาย  66.0   พระนครศรีอยุธยา
# 12641     ชาย  29.0          ปทุมธานี
# 12642    หญิง  50.0           ราชบุรี
# 12643     ชาย  39.0              สตูล
# 12644    หญิง  49.0       สมุทรปราการ
# 12645    หญิง  44.0            ชลบุรี
# 12646     ชาย  18.0       สมุทรปราการ
# 12647     ชาย  42.0     กรุงเทพมหานคร
# 12648    หญิง  44.0            ชลบุรี
# 12649    หญิง  52.0             ระยอง
# 12650    หญิง  23.0             ระยอง
# 12651    หญิง  29.0             ระยอง
# 12652    หญิง  22.0               ตาก

# %%
this_data_updated.isnull().any()  #ไม่มีค่า missing แล้ว
# Out:
# sex                  False
# age                  False
# province_of_onset    False
# dtype: bool

# %% [markdown]
# ### 2. แทนด้วยค่าที่เหมาะสม
#
#
# *   ตามใจคนทำ
# *   ค่ากลาง

# %% [markdown]
# #### ตามใจคนทำ

# %%
data_covid.head()  #แสดง 5 ค่าแรก
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [5 rows x 10 columns]

# %%
data_covid_fillasiwant = data_covid.fillna(value={'sex':'หญิง'})  #เรามีข้อมูลว่า เพศหญิงมีเยอะกว่าเพศชาย

# %%
data_covid_fillasiwant.isnull().any()  #คอลัมน์ sex ไม่มี missing
# Out:
# No.                      False
# announce_date            False
# notification_date         True
# sex                      False
# age                       True
# nationality               True
# province_of_isolation     True
# province_of_onset         True
# district_of_onset         True
# risk                      True
# dtype: bool

# %% [markdown]
# #### แทนด้วยค่ากลาง

# %%
data_covid['age']
# Out:
# 0        61.0
# 1        74.0
# 2        73.0
# 3        68.0
# 4        66.0
#          ...
# 12648    44.0
# 12649    52.0
# 12650    23.0
# 12651    29.0
# 12652    22.0
# Name: age, Length: 12653, dtype: float64

# %%
data_covid['age'].mean()  #คำนวณค่าเฉลี่ย ของคอลัมน์ age
# Out:
# 38.054748339151

# %%
data_covid_fillwithmean = data_covid.fillna(value={'age':data_covid['age'].mean()})  #เติม missing ด้วยค่าเฉลี่ย

# %%
data_covid_fillwithmean.isnull().any()  #คอลัมน์ age ไม่มีค่า missing แล้ว
# Out:
# No.                      False
# announce_date            False
# notification_date         True
# sex                       True
# age                      False
# nationality               True
# province_of_isolation     True
# province_of_onset         True
# district_of_onset         True
# risk                      True
# dtype: bool

# %% [markdown]
# ### การวนลูป record ในตาราง  (```.iterrows```)

# %%
this_data = data_covid[['sex','age','province_of_onset']]  #ตัด Data มาจาก Data covid
this_data
# Out:
#         sex   age province_of_onset
# 0      หญิง  61.0     กรุงเทพมหานคร
# 1      หญิง  74.0     กรุงเทพมหานคร
# 2      หญิง  73.0            นครปฐม
# 3       ชาย  68.0     กรุงเทพมหานคร
# 4      หญิง  66.0     กรุงเทพมหานคร
# ...     ...   ...               ...
# 12648  หญิง  44.0            ชลบุรี
# 12649  หญิง  52.0             ระยอง
# 12650  หญิง  23.0             ระยอง
# 12651  หญิง  29.0             ระยอง
# 12652  หญิง  22.0               ตาก
#
# [12653 rows x 3 columns]

# %%
for each_row in this_data.iterrows():   #function iterrows จะสร้าง list ในแต่ละแถวเป็นฟังก์ชันของ pandas เพราะหลัง in ต้องเป็น list
    # print(each_row)  #คือ print แถวที่ 0 
    # print(each_row[1])  #คือ print แถวที่ 1 ที่มีข้อมูล
    # print(each_row[1]['sex'])  #ดึงค่าในแต่ละแถว
    if (each_row[1]['age'] <= 20) and (each_row[1]['province_of_onset'] == 'ขอนแก่น'):  # print แถวที่ age น้อยกว่า เท่ากับ 20   และจังหวัดขอนแก่น
        print(each_row)  # มี 5 คน
# Out:
# (1466, sex                      ชาย
# age                       19
# province_of_onset    ขอนแก่น
# Name: 1466, dtype: object)
# (9333, sex                      ชาย
# age                       17
# province_of_onset    ขอนแก่น
# Name: 9333, dtype: object)
# (9334, sex                      ชาย
# age                       20
# province_of_onset    ขอนแก่น
# Name: 9334, dtype: object)
# (10610, sex                      ชาย
# age                       17
# province_of_onset    ขอนแก่น
# Name: 10610, dtype: object)
# (11517, sex                      ชาย
# age                       12
# province_of_onset    ขอนแก่น
# Name: 11517, dtype: object)
# (11697, sex                     หญิง
# age                       17
# province_of_onset    ขอนแก่น
# Name: 11697, dtype: object)

# %% [markdown]
# ### การวนลูป แบบมองตารางแพนด้าส์(pandas dataframe) เป็น numpy array  (```.iloc```)

# %%
for each_row in range(this_data.shape[0]):
    if (this_data.iloc[each_row,1] <= 20) and (this_data.iloc[each_row,2] == 'ขอนแก่น'):  #each_row คือ ตัวเลข
        print(each_row)  # ถ้า age น้อยกว่า เท่ากับ 20   และจังหวัดขอนแก่น  ให้ print ออกมา
        print(this_data.iloc[each_row,:])   # ได้มาเฉพาะค่าที่เาต้องการ
# Out:
# 1466
# sex                      ชาย
# age                       19
# province_of_onset    ขอนแก่น
# Name: 1466, dtype: object
# 9333
# sex                      ชาย
# age                       17
# province_of_onset    ขอนแก่น
# Name: 9333, dtype: object
# 9334
# sex                      ชาย
# age                       20
# province_of_onset    ขอนแก่น
# Name: 9334, dtype: object
# 10610
# sex                      ชาย
# age                       17
# province_of_onset    ขอนแก่น
# Name: 10610, dtype: object
# 11517
# sex                      ชาย
# age                       12
# province_of_onset    ขอนแก่น
# Name: 11517, dtype: object
# 11697
# sex                     หญิง
# age                       17
# province_of_onset    ขอนแก่น
# Name: 11697, dtype: object

# %% [markdown]
# ## Quiz ตัดตารางออกมาเฉพาะปี 2021 ```announce_date``` ในปี 2021
#
# **Hint**
# *   วนลูปหา index ของปี 2021
# *   ตัดตารางมาเฉพาะ ปี 2021

# %%
TF=list()
for each_row in data_covid.iterrows():
    if each_row[1]['announce_date'].split('/')[2] == '2021':
        TF.append(True)
    else:
        TF.append(False)

data_covid[TF].head()
# Out:
#        No.  ...                                               risk
# 6884  6885  ...                                  Cluster สมุทรสาคร
# 6885  6886  ...                                      Cluster ระยอง
# 6886  6887  ...                                        สถานบันเทิง
# 6887  6888  ...                                  Cluster สมุทรสาคร
# 6888  6889  ...  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
#
# [5 rows x 10 columns]

# %% [markdown]
# ### HW กลุ่ม 2 || เลือกข้อมูลมาเฉพาะวัน announce_date เป็นวันที่ 1-20

# %%
TF2=list()  #สร้าง list ว่าง
for each_row in data_covid.iterrows(): #วนลูปใน data_covid.iterrows
    if each_row[1]['announce_date'].split('/')[1] <= '20':  #จะ split column announce_date  โดยจะกำหนดเครื่องหมาย /  เป็นตัวคั่นในการ split คือ split หลัง / ตัวที่ 1
        TF2.append(True)  #สร้าง List เปล่า ๆ ก่อนที่จะเติมค่าลงไปใน List ด้วยการใช้ .append() #เก็บค่า true มีขนาดความยาวเท่ากับจำนวนแถวตาราง เพื่อเอาไปเลือก
    else:
        TF2.append(False)  #เอา false ไปใส่ใน list TF2    row ไหนตรงกับ true ก็เอา

data_covid[TF2]  #แสดงค่าทั้งหมด
# Out:
#          No.  ...                                         risk
# 0          1  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          2  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 32        33  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 33        34  ...              บุคลากรด้านการแพทย์และสาธารณสุข
# 34        35  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...      ...  ...                                          ...
# 12648  12649  ...                             State Quarantine
# 12649  12650  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12650  12651  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651  12652  ...                                Cluster ระยอง
# 12652  12653  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [5135 rows x 10 columns]

# %%
TF2=list()  #สร้าง list ว่าง
for each_row in data_covid.iterrows(): #วนลูปใน data_covid.iterrows
    if each_row[1]['announce_date'].split('/')[1] <= '20':  #จะ split column announce_date  โดยจะกำหนดเครื่องหมาย /  เป็นตัวคั่นในการ split คือ split หลัง / ตัวที่ 1
        TF2.append(True)  #สร้าง List เปล่า ๆ ก่อนที่จะเติมค่าลงไปใน List ด้วยการใช้ .append()
    else:
        TF2.append(False)

data_covid[TF2].head()  #แสดง 5 ค่าแรก
# Out:
#     No.  ...                                         risk
# 0     1  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1     2  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 32   33  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 33   34  ...              บุคลากรด้านการแพทย์และสาธารณสุข
# 34   35  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [5 rows x 10 columns]

# %% [markdown]
# # Function ตัวช่วยใน pandas

# %% [markdown]
# ### ```.describe()``` คำนวณค่าทางสถิติของข้อมูลที่เป็นตัวเลข

# %%
data_covid.describe()
# Out:
#                 No.          age
# count  12653.000000  8881.000000
# mean    6327.000000    38.054748
# std     3652.750813    15.125178
# min        1.000000     0.100000
# 25%     3164.000000    27.000000
# 50%     6327.000000    36.000000
# 75%     9490.000000    48.000000
# max    12653.000000    97.000000

# %% [markdown]
# ### ```.mean()``` คำนวณค่าเฉลี่ยของข้อมูลโดยไม่สนใจ missing

# %%
data_covid[data_covid['sex']=='ชาย']['age'].mean()
# Out:
# 39.46076940331987

# %% [markdown]
# ### ```.isnull()```

# %%
data_covid.isnull()  #ดูค่า missing ว่ามีมั้ย ถ้ามีจะเป็น True  ไม่มีจะเป็น false
# Out:
#          No.  announce_date  ...  district_of_onset   risk
# 0      False          False  ...               True  False
# 1      False          False  ...               True  False
# 2      False          False  ...              False  False
# 3      False          False  ...               True  False
# 4      False          False  ...               True  False
# ...      ...            ...  ...                ...    ...
# 12648  False          False  ...              False  False
# 12649  False          False  ...              False  False
# 12650  False          False  ...              False  False
# 12651  False          False  ...              False  False
# 12652  False          False  ...              False  False
#
# [12653 rows x 10 columns]

# %% [markdown]
# # next
# *   .describe
# *   .mean
# *   HW วนลูป missing .isnull
# *   ต่อตารางแกน X แกน y
# *   .groupby
# *   save table
